# %% [markdown]
# # 対数変換 (LightGBM)
#
# Predicting Road Accident Risk (Playground Series - Season 5, Episode 10)
#
# https://www.kaggle.com/competitions/playground-series-s5e10/overview

# %%
import lightgbm as lgb
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
import seaborn as sns
from sklearn.metrics import mean_squared_error
from sklearn.model_selection import KFold

from utils import check_df

# %% [markdown]
# ## パラメータ設定

# %%
class CFG:
    exp_name = "exp06"
    seed = 123
    n_splits = 5

    # LightGBM parameters
    num_leaves = 16
    max_depth = -1
    learning_rate = 0.1

# %% [markdown]
# ## データ読み込み

# %%
class Paths:
    p = "./input/"
    train = p + "train.csv"
    test = p + "test.csv"
    sample = p + "sample_submission.csv"
    submission = f"./output/{CFG.exp_name}.csv"

# %%
train = pd.read_csv(Paths.train)
test = pd.read_csv(Paths.test)
train.shape, test.shape
# Out:
# ((517754, 14), (172585, 13))

# %%
if False:
    display(check_df(train))
    display(check_df(test))

# %% [markdown]
# ## 特徴量エンジニアリング

# %%
def feature_engineering(df):
    df = df.drop(columns=["id"])
    # カテゴリ変数の処理
    cat_cols = df.select_dtypes(include=["object"]).columns.tolist()
    for col in cat_cols:
        df[col] = df[col].astype("category")

    # bool型をint型に変換
    bool_cols = df.select_dtypes(include=["bool"]).columns.tolist()
    for col in bool_cols:
        df[col] = df[col].astype(int)

    # 目的変数の対数変換
    target = "accident_risk"
    if target in df.columns:
        df[target] = np.log1p(df[target])

    # TODO: 追加の特徴量エンジニアリングをここに実装

    return df

# %%
train_processed = feature_engineering(train)
test_processed = feature_engineering(test)

# %%
# データ分割
target = "accident_risk"
x_train = train_processed.drop(columns=[target])
y_train = train_processed[target]
x_test = test_processed.copy()

# %%
if False:
    train[target].hist(bins=50)

# %% [markdown]
# ## クロスバリデーション

# %%
params = {
    "boosting_type": "gbdt",
    "objective": "regression",
    "metric": "rmse",
    "learning_rate": CFG.learning_rate,
    "num_leaves": CFG.num_leaves,
    "n_estimators": 100000,
    "random_state": CFG.seed,
    "verbose": -1,
}

# %%
cv = KFold(n_splits=CFG.n_splits, shuffle=True, random_state=CFG.seed)

y_test_pred = np.zeros(len(x_test))
metrics = []
imp = pd.DataFrame()

for fold, (train_idx, val_idx) in enumerate(cv.split(x_train, y_train)):
    print("=" * 10, f"Fold {fold + 1}", "=" * 10)
    x_tr, y_tr = x_train.iloc[train_idx], y_train.iloc[train_idx]
    x_va, y_va = x_train.iloc[val_idx], y_train.iloc[val_idx]

    model = lgb.LGBMRegressor(**params)

    model.fit(
        x_tr,
        y_tr,
        eval_set=[(x_tr, y_tr), (x_va, y_va)],
        eval_metric="rmse",
        callbacks=[
            lgb.early_stopping(stopping_rounds=100, verbose=False),
            lgb.log_evaluation(100),
        ],
    )

    y_tr_pred = model.predict(x_tr)
    y_va_pred = model.predict(x_va)
    # y_test_pred += model.predict(x_test) / CFG.n_splits
    y_test_pred += np.expm1(model.predict(x_test)) / CFG.n_splits

    rmse_tr = np.sqrt(mean_squared_error(np.expm1(y_tr), np.expm1(y_tr_pred)))
    rmse_va = np.sqrt(mean_squared_error(np.expm1(y_va), np.expm1(y_va_pred)))

    metrics.append([fold + 1, rmse_tr, rmse_va])

    _imp = pd.DataFrame(
        {
            "feature": x_train.columns,
            "importance": model.feature_importances_,
            "fold": fold + 1,
        }
    )
    imp = pd.concat([imp, _imp], axis=0, ignore_index=True)
# Out:
# ========== Fold 1 ==========
# [100]	training's rmse: 0.0419916	valid_1's rmse: 0.0419911
# [200]	training's rmse: 0.0418198	valid_1's rmse: 0.0418798
# [300]	training's rmse: 0.041716	valid_1's rmse: 0.0418335
# [400]	training's rmse: 0.0416399	valid_1's rmse: 0.0418179
# [500]	training's rmse: 0.0415585	valid_1's rmse: 0.0418008
# [600]	training's rmse: 0.0414917	valid_1's rmse: 0.0417928
# [700]	training's rmse: 0.0414288	valid_1's rmse: 0.0417816
# [800]	training's rmse: 0.041374	valid_1's rmse: 0.0417796
# [900]	training's rmse: 0.0413206	valid_1's rmse: 0.0417769
# [1000]	training's rmse: 0.0412717	valid_1's rmse: 0.0417799
# ========== Fold 2 ==========
# [100]	training's rmse: 0.0419555	valid_1's rmse: 0.0421808
# [200]	training's rmse: 0.041788	valid_1's rmse: 0.0420745
# [300]	training's rmse: 0.0416793	valid_1's rmse: 0.042023
# [400]	training's rmse: 0.0415889	valid_1's rmse: 0.0419956
# [500]	training's rmse: 0.0415195	valid_1's rmse: 0.0419783
# [600]	training's rmse: 0.041458	valid_1's rmse: 0.0419706
# [700]	training's rmse: 0.0413925	valid_1's rmse: 0.0419551
# [800]	training's rmse: 0.0413346	valid_1's rmse: 0.041951
# [900]	training's rmse: 0.0412795	valid_1's rmse: 0.0419472
# [1000]	training's rmse: 0.0412231	valid_1's rmse: 0.0419477
# ========== Fold 3 ==========
# [100]	training's rmse: 0.0419891	valid_1's rmse: 0.0420712
# [200]	training's rmse: 0.0418241	valid_1's rmse: 0.0419552
# [300]	training's rmse: 0.041714	valid_1's rmse: 0.0418903
# [400]	training's rmse: 0.0416231	valid_1's rmse: 0.0418475
# [500]	training's rmse: 0.0415521	valid_1's rmse: 0.0418304
# [600]	training's rmse: 0.0414935	valid_1's rmse: 0.0418191
# [700]	training's rmse: 0.0414371	valid_1's rmse: 0.041813
# [800]	training's rmse: 0.0413792	valid_1's rmse: 0.0418117
# ========== Fold 4 ==========
# [100]	training's rmse: 0.0420064	valid_1's rmse: 0.0419057
# [200]	training's rmse: 0.0418311	valid_1's rmse: 0.0417997
# [300]	training's rmse: 0.0417245	valid_1's rmse: 0.0417575
# [400]	training's rmse: 0.041642	valid_1's rmse: 0.041736
# [500]	training's rmse: 0.0415708	valid_1's rmse: 0.0417195
# [600]	training's rmse: 0.0415075	valid_1's rmse: 0.0417091
# [700]	training's rmse: 0.0414446	valid_1's rmse: 0.0417059
# [800]	training's rmse: 0.0413898	valid_1's rmse: 0.0416997
# [900]	training's rmse: 0.0413345	valid_1's rmse: 0.0416982
# [1000]	training's rmse: 0.0412829	valid_1's rmse: 0.0416986
# ========== Fold 5 ==========
# [100]	training's rmse: 0.0419824	valid_1's rmse: 0.0420296
# [200]	training's rmse: 0.0418062	valid_1's rmse: 0.0419211
# [300]	training's rmse: 0.0417011	valid_1's rmse: 0.0418808
# [400]	training's rmse: 0.0416262	valid_1's rmse: 0.0418636
# [500]	training's rmse: 0.041558	valid_1's rmse: 0.0418521
# [600]	training's rmse: 0.0414859	valid_1's rmse: 0.0418348
# [700]	training's rmse: 0.0414231	valid_1's rmse: 0.0418298

# %%
imp = imp.groupby("feature")["importance"].mean().sort_values(ascending=False)

plt.figure(figsize=(8, 5))
sns.barplot(x=imp.head(30).values, y=imp.head(30).index)
plt.title("Top 30 Feature Importances")
plt.xlabel("Importance")
plt.ylabel("Feature")
plt.show()

# %%
metrics_array = np.array(metrics)

print(
    "[cv ] tr: {:.5f} ± {:.5f}, va: {:.5f} ± {:.5f}".format(
        metrics_array[:, 1].mean(),
        metrics_array[:, 1].std(),
        metrics_array[:, 2].mean(),
        metrics_array[:, 2].std(),
    )
)
# Out:
# [cv ] tr: 0.05548 ± 0.00009, va: 0.05612 ± 0.00006

# %% [markdown]
# ## 予測・提出

# %%
df_submit = pd.DataFrame(
    {
        "id": test["id"],
        "accident_risk": y_test_pred,
    }
)
df_submit.to_csv(Paths.submission, index=False)
