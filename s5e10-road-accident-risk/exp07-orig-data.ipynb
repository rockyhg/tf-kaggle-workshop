# %% [markdown]
# # Simulated Roads Accident Data の利用 (LightGBM)
#
# Predicting Road Accident Risk (Playground Series - Season 5, Episode 10)
#
# https://www.kaggle.com/competitions/playground-series-s5e10/overview

# %%
import sys
sys.path.append("../utils")

import lightgbm as lgb
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
import seaborn as sns
from sklearn.metrics import mean_squared_error
from sklearn.model_selection import KFold

from utils import check_df

# %% [markdown]
# ## パラメータ設定

# %%
class CFG:
    exp_name = "exp07"
    seed = 123
    n_splits = 5

    # LightGBM parameters
    num_leaves = 16
    max_depth = -1
    learning_rate = 0.1

# %% [markdown]
# ## データ読み込み

# %%
class Paths:
    p = "./input/"
    train = p + "train.csv"
    test = p + "test.csv"
    sample = p + "sample_submission.csv"
    submission = f"./output/{CFG.exp_name}.csv"

# %%
train = pd.read_csv(Paths.train)
test = pd.read_csv(Paths.test)
train.shape, test.shape
# Out:
# ((517754, 14), (172585, 13))

# %%
# オリジナルデータの読み込み
orig = []
for k in [2, 10, 100]:
    path = Paths.p + f"synthetic_road_accidents_{k}k.csv"
    df = pd.read_csv(path)
    orig.append(df)

orig = pd.concat(orig, axis=0)
orig["id"] = np.arange(len(orig)) + test["id"].max() + 1
orig = orig[train.columns]
orig.shape
# Out:
# (112000, 14)

# %%
orig["is_original"] = True
train["is_original"] = False
test["is_original"] = False

# %%
all_train = pd.concat([train, orig], axis=0, ignore_index=True)
all_train.shape
# Out:
# (629754, 15)

# %%
if True:
    display(check_df(all_train))
    display(check_df(test))
# Out:
#                     Column   dtypes  NaN Count  Nunique  \
# 0                       id    int64          0   629754
# 1                road_type   object          0        3
# 2                num_lanes    int64          0        4
# 3                curvature  float64          0      261
# 4              speed_limit    int64          0        5
# 5                 lighting   object          0        3
# 6                  weather   object          0        3
# 7       road_signs_present     bool          0        2
# 8              public_road     bool          0        2
# 9              time_of_day   object          0        3
# 10                 holiday     bool          0        2
# 11           school_season     bool          0        2
# 12  num_reported_accidents    int64          0       11
# 13           accident_risk  float64          0      101
# 14             is_original     bool          0        2
#
#                     Unique Values
# 0              > 10 unique values
# 1         [urban, rural, highway]
# 2                    [2, 4, 1, 3]
# 3              > 10 unique values
# 4            [35, 70, 60, 45, 25]
# 5          [daylight, dim, night]
# 6           [rainy, clear, foggy]
# 7                   [False, True]
# 8                   [True, False]
# 9   [afternoon, evening, morning]
# 10                  [False, True]
# 11                  [True, False]
# 12             > 10 unique values
# 13             > 10 unique values
# 14                  [False, True]
#                     Column   dtypes  NaN Count  Nunique  \
# 0                       id    int64          0   172585
# 1                road_type   object          0        3
# 2                num_lanes    int64          0        4
# 3                curvature  float64          0      195
# 4              speed_limit    int64          0        5
# 5                 lighting   object          0        3
# 6                  weather   object          0        3
# 7       road_signs_present     bool          0        2
# 8              public_road     bool          0        2
# 9              time_of_day   object          0        3
# 10                 holiday     bool          0        2
# 11           school_season     bool          0        2
# 12  num_reported_accidents    int64          0        8
# 13             is_original     bool          0        1
#
#                     Unique Values
# 0              > 10 unique values
# 1         [highway, urban, rural]
# 2                    [2, 3, 4, 1]
# 3              > 10 unique values
# 4            [45, 35, 25, 70, 60]
# 5          [night, dim, daylight]
# 6           [clear, foggy, rainy]
# 7                   [True, False]
# 8                   [True, False]
# 9   [afternoon, evening, morning]
# 10                  [True, False]
# 11                  [True, False]
# 12       [1, 0, 2, 3, 4, 6, 5, 7]
# 13                        [False]

# %% [markdown]
# ## 特徴量エンジニアリング

# %%
def feature_engineering(df):
    df = df.drop(columns=["id"])
    # カテゴリ変数の処理
    cat_cols = df.select_dtypes(include=["object"]).columns.tolist()
    for col in cat_cols:
        df[col] = df[col].astype("category")

    # bool型をint型に変換
    bool_cols = df.select_dtypes(include=["bool"]).columns.tolist()
    for col in bool_cols:
        df[col] = df[col].astype(int)

    # TODO: 追加の特徴量エンジニアリングをここに実装

    return df

# %%
train_processed = feature_engineering(all_train)
test_processed = feature_engineering(test)

# %%
# データ分割
target = "accident_risk"
x_train = train_processed.drop(columns=[target])
y_train = train_processed[target]
x_test = test_processed.copy()

# %%
if False:
    train[target].hist(bins=50)

# %% [markdown]
# ## クロスバリデーション

# %%
params = {
    "boosting_type": "gbdt",
    "objective": "regression",
    "metric": "rmse",
    "learning_rate": CFG.learning_rate,
    "num_leaves": CFG.num_leaves,
    "n_estimators": 100000,
    "random_state": CFG.seed,
    "verbose": -1,
}

# %%
cv = KFold(n_splits=CFG.n_splits, shuffle=True, random_state=CFG.seed)

y_test_pred = np.zeros(len(x_test))
metrics = []
imp = pd.DataFrame()

for fold, (train_idx, val_idx) in enumerate(cv.split(x_train, y_train)):
    print("=" * 10, f"Fold {fold + 1}", "=" * 10)
    x_tr, y_tr = x_train.iloc[train_idx], y_train.iloc[train_idx]
    x_va, y_va = x_train.iloc[val_idx], y_train.iloc[val_idx]

    model = lgb.LGBMRegressor(**params)

    model.fit(
        x_tr,
        y_tr,
        eval_set=[(x_tr, y_tr), (x_va, y_va)],
        eval_metric="rmse",
        callbacks=[
            lgb.early_stopping(stopping_rounds=100, verbose=False),
            lgb.log_evaluation(100),
        ],
    )

    y_tr_pred = model.predict(x_tr)
    y_va_pred = model.predict(x_va)
    y_test_pred += model.predict(x_test) / CFG.n_splits

    rmse_tr = np.sqrt(mean_squared_error(y_tr, y_tr_pred))
    rmse_va = np.sqrt(mean_squared_error(y_va, y_va_pred))

    metrics.append([fold + 1, rmse_tr, rmse_va])

    _imp = pd.DataFrame(
        {
            "feature": x_train.columns,
            "importance": model.feature_importances_,
            "fold": fold + 1,
        }
    )
    imp = pd.concat([imp, _imp], axis=0, ignore_index=True)
# Out:
# ========== Fold 1 ==========
# [100]	training's rmse: 0.0554066	valid_1's rmse: 0.0555464
# [200]	training's rmse: 0.0551788	valid_1's rmse: 0.0553847
# [300]	training's rmse: 0.0550369	valid_1's rmse: 0.0553093
# [400]	training's rmse: 0.0549387	valid_1's rmse: 0.0552791
# [500]	training's rmse: 0.0548554	valid_1's rmse: 0.0552607
# [600]	training's rmse: 0.0547696	valid_1's rmse: 0.0552378
# [700]	training's rmse: 0.0546976	valid_1's rmse: 0.0552247
# [800]	training's rmse: 0.0546271	valid_1's rmse: 0.0552101
# [900]	training's rmse: 0.0545585	valid_1's rmse: 0.0551973
# [1000]	training's rmse: 0.0544912	valid_1's rmse: 0.0551861
# [1100]	training's rmse: 0.0544281	valid_1's rmse: 0.0551825
# [1200]	training's rmse: 0.0543674	valid_1's rmse: 0.0551785
# ========== Fold 2 ==========
# [100]	training's rmse: 0.0554608	valid_1's rmse: 0.0554794
# [200]	training's rmse: 0.0551952	valid_1's rmse: 0.0552896
# [300]	training's rmse: 0.0550625	valid_1's rmse: 0.0552237
# [400]	training's rmse: 0.0549652	valid_1's rmse: 0.0551942
# [500]	training's rmse: 0.0548588	valid_1's rmse: 0.0551513
# [600]	training's rmse: 0.0547735	valid_1's rmse: 0.0551288
# [700]	training's rmse: 0.0547003	valid_1's rmse: 0.0551157
# [800]	training's rmse: 0.0546277	valid_1's rmse: 0.0551039
# [900]	training's rmse: 0.0545629	valid_1's rmse: 0.0551046
# [1000]	training's rmse: 0.0544959	valid_1's rmse: 0.0551005
# [1100]	training's rmse: 0.054439	valid_1's rmse: 0.0551008
# ========== Fold 3 ==========
# [100]	training's rmse: 0.0554731	valid_1's rmse: 0.0554446
# [200]	training's rmse: 0.0552205	valid_1's rmse: 0.0552387
# [300]	training's rmse: 0.0550786	valid_1's rmse: 0.0551653
# [400]	training's rmse: 0.0549532	valid_1's rmse: 0.055106
# [500]	training's rmse: 0.0548593	valid_1's rmse: 0.0550779
# [600]	training's rmse: 0.054778	valid_1's rmse: 0.0550499
# [700]	training's rmse: 0.054704	valid_1's rmse: 0.0550337
# [800]	training's rmse: 0.0546387	valid_1's rmse: 0.0550286
# [900]	training's rmse: 0.0545673	valid_1's rmse: 0.0550163
# [1000]	training's rmse: 0.0545039	valid_1's rmse: 0.0550065
# ========== Fold 4 ==========
# [100]	training's rmse: 0.0554682	valid_1's rmse: 0.0553568
# [200]	training's rmse: 0.0552278	valid_1's rmse: 0.0551855
# [300]	training's rmse: 0.0550886	valid_1's rmse: 0.0551168
# [400]	training's rmse: 0.0549802	valid_1's rmse: 0.0550771
# [500]	training's rmse: 0.054884	valid_1's rmse: 0.0550375
# [600]	training's rmse: 0.0548019	valid_1's rmse: 0.0550202
# [700]	training's rmse: 0.054732	valid_1's rmse: 0.0550081
# [800]	training's rmse: 0.0546656	valid_1's rmse: 0.0550029
# [900]	training's rmse: 0.054602	valid_1's rmse: 0.0549984
# [1000]	training's rmse: 0.0545391	valid_1's rmse: 0.0549945
# [1100]	training's rmse: 0.0544855	valid_1's rmse: 0.0549924
# [1200]	training's rmse: 0.05442	valid_1's rmse: 0.0549866
# [1300]	training's rmse: 0.0543688	valid_1's rmse: 0.0549886
# ========== Fold 5 ==========
# [100]	training's rmse: 0.0554238	valid_1's rmse: 0.0557382
# [200]	training's rmse: 0.0551673	valid_1's rmse: 0.0555316
# [300]	training's rmse: 0.0550048	valid_1's rmse: 0.0554179
# [400]	training's rmse: 0.0548945	valid_1's rmse: 0.0553697
# [500]	training's rmse: 0.0548005	valid_1's rmse: 0.055338
# [600]	training's rmse: 0.0547189	valid_1's rmse: 0.0553152
# [700]	training's rmse: 0.0546422	valid_1's rmse: 0.0552968
# [800]	training's rmse: 0.0545754	valid_1's rmse: 0.0552884
# [900]	training's rmse: 0.0545129	valid_1's rmse: 0.055282
# [1000]	training's rmse: 0.0544507	valid_1's rmse: 0.0552769
# [1100]	training's rmse: 0.054391	valid_1's rmse: 0.0552754

# %%
imp = imp.groupby("feature")["importance"].mean().sort_values(ascending=False)

plt.figure(figsize=(8, 5))
sns.barplot(x=imp.head(30).values, y=imp.head(30).index)
plt.title("Top 30 Feature Importances")
plt.xlabel("Importance")
plt.ylabel("Feature")
plt.show()

# %%
metrics_array = np.array(metrics)

print(
    "[cv ] tr: {:.5f} ± {:.5f}, va: {:.5f} ± {:.5f}".format(
        metrics_array[:, 1].mean(),
        metrics_array[:, 1].std(),
        metrics_array[:, 2].mean(),
        metrics_array[:, 2].std(),
    )
)
# Out:
# [cv ] tr: 0.05444 ± 0.00004, va: 0.05511 ± 0.00011

# %% [markdown]
# ## 予測・提出

# %%
df_submit = pd.DataFrame(
    {
        "id": test["id"],
        "accident_risk": y_test_pred,
    }
)
df_submit.to_csv(Paths.submission, index=False)
